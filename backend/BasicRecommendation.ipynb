# %%
import pandas as pd
import numpy as np
from re import sub
from ast import literal_eval
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

df = pd.read_csv('../data/dataset.csv', encoding='latin1')

# %%
df = df.iloc[:, 1:].copy()
df = df.dropna()

# %%
df['City'] = df['City'].str.capitalize()
df['Cuisine Style'] = df['Cuisine Style'].str.lower()
df['keyword'] = df['keyword'].str.lower()
df['keyword'] = df['keyword'].str.strip()

df['Cuisine Style'] = df['Cuisine Style'].apply(lambda x: ' '.join(x.split(',')).split())
df['keyword'] = df['keyword'].apply(lambda x: sub(' +', ' ', x))

# %%
df = df.sample(5000)
df.sample(10)
# Out:
#                           Name        City  \
# 89980        Slurp Ramen Joint  Copenhagen
# 65634          Mucha Nie Siada      Warsaw
# 97251           The First Lady  Copenhagen
# 56511          Le Tre Piramidi        Rome
# 95953   Thai Pot - Bedfordbury      London
# 100837        Trattoria Angelo        Rome
# 6165                    BENI's      Lisbon
# 17528              Caffe Amore      Dublin
# 7701              Bar La Santa      Madrid
# 44978              Keyser Soze      Berlin
#
#                                             Cuisine Style  Ranking  Rating  \
# 89980   [japanese, asian, soups, vegetarianfriendly, v...    122.0     4.5
# 65634                                          [european]   1155.0     5.0
# 97251          [european, bar, pub, scandinavian, danish]    895.0     4.0
# 56511                     [pizza, mediterranean, italian]   3836.0     4.0
# 95953   [asian, thai, vegetarianfriendly, veganoptions...   1882.0     4.0
# 100837  [italian, pizza, mediterranean, vegetarianfrie...   2703.0     3.5
# 6165       [italian, french, american, belgian, european]   3469.0     3.0
# 17528   [italian, pizza, cafe, mediterranean, european...    255.0     4.5
# 7701    [cafe, delicatessen, bar, pub, mediterranean, ...    933.0     4.5
# 44978   [german, bar, cafe, european, centraleuropean,...   1135.0     3.5
#
#        Price Range                                            keyword
# 89980       casual           copenhagen casual vegetarian soups asian
# 65634        cheap                                       warsaw cheap
# 97251       casual         copenhagen casual pub bar northerneuropean
# 56511       casual                    rome casual mediterranean pizza
# 95953       casual                     london casual vegetarian asian
# 100837      casual         rome casual vegetarian mediterranean pizza
# 6165         cheap         lisbon cheap northamerican westerneuropean
# 17528       casual  dublin casual cafe vegetarian mediterranean pizza
# 7701        casual  madrid casual pub cafe bar mediterranean weste...
# 44978       casual  berlin casual cafe bar vegetarian centraleurop...

# %%
# Import CountVectorizer and create the count matrix
count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(df['keyword'])

# %%
# Compute the Cosine Similarity matrix based on the count_matrix
cosine_sim = cosine_similarity(count_matrix, count_matrix)

# %%
# Reset index of our main DataFrame and construct reverse mapping as before
df = df.reset_index()
indices = pd.Series(df.index, index=df['Name'])

# %%
# Function that takes in movie title as input and outputs most similar movies
def get_recommendations(title, cosine_sim=cosine_sim, num=10):
    # Get the index of the movie that matches the title
    idx = indices[title]

    # Get the pairwsie similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar movies
    sim_scores = sim_scores[1:num+1]

    # Get the restaurants indices
    restaurants_indices = [i[0] for i in sim_scores]

    # Return the top 10 most similar movies
    return df['Name'].iloc[restaurants_indices]

# %%
df.head(15)
# Out:
#      index                            Name        City  \
# 0    66689                 Nass Restaurant   Barcelona
# 1    96832                   The Coal Hole      London
# 2    10060          Bierhalle - CH Arkadia      Warsaw
# 3    56809                   Le pebon d'or       Paris
# 4    93649                            TZOM      Berlin
# 5   101403               Triadou Haussmann       Paris
# 6    35154                  Gefstiki Gonia      Athens
# 7     3550                     Anise - Bar      London
# 8    23318                      Copenhagen      Madrid
# 9    13044                        Briciole       Milan
# 10   79931                Restaurant Blume      Zurich
# 11   34378                        Gaffurio       Milan
# 12   78576     Ratuszowa Krzysztof Janarek      Krakow
# 13   43643                           K-Bar  Copenhagen
# 14   62152  Massenzio Ai Fori e Ristorante        Rome
#
#                                         Cuisine Style  Ranking  Rating  \
# 0   [mediterranean, european, spanish, vegetarianf...    435.0     4.5
# 1             [bar, british, pub, vegetarianfriendly]   1150.0     4.0
# 2            [bar, polish, european, centraleuropean]    950.0     3.5
# 3                                           [african]   8404.0     4.0
# 4           [african, italian, mediterranean, fusion]   2868.0     5.0
# 5                             [french, bar, european]   6797.0     3.5
# 6   [mediterranean, barbecue, greek, vegetarianfri...     58.0     4.5
# 7                                  [indian, bar, pub]   7712.0     4.0
# 8   [spanish, vegetarianfriendly, veganoptions, gl...   1221.0     4.0
# 9   [italian, pizza, seafood, mediterranean, europ...    859.0     4.0
# 10          [swiss, european, diner, centraleuropean]   1267.0     5.0
# 11                                   [italian, pizza]   5931.0     3.0
# 12        [polish, bar, european, vegetarianfriendly]    316.0     4.0
# 13                                     [contemporary]    333.0     4.5
# 14  [italian, pizza, mediterranean, soups, vegetar...   2532.0     3.5
#
#    Price Range                                            keyword
# 0       casual  barcelona casual vegetarian mediterranean west...
# 1       casual   london casual pub bar vegetarian westerneuropean
# 2       casual                  warsaw casual bar centraleuropean
# 3       casual                               paris casual african
# 4        cheap          berlin cheap mediterranean african fusion
# 5       casual                   paris casual bar westerneuropean
# 6        cheap  athens cheap vegetarian mediterranean grill ea...
# 7       casual                        london casual pub bar asian
# 8       casual           madrid casual vegetarian westerneuropean
# 9        cheap  milan cheap vegetarian mediterranean seafood p...
# 10       fancy                       zurich fancy centraleuropean
# 11       cheap                                  milan cheap pizza
# 12      casual       krakow casual bar vegetarian centraleuropean
# 13      casual                     copenhagen casual contemporary
# 14      casual   rome casual vegetarian mediterranean pizza soups

# %%
restaurant_name = input('Restaurant Name:')
recommendations = get_recommendations(restaurant_name)
recommendations
# Out:
# Restaurant Name:Gaffurio
# 2843    Al Meazza Ristorante Pizzeria
# 3133      Pizzeria Trattoria S. Maria
# 444                  Pizzeria Del 333
# 731              Pizzeria Dell'Angelo
# 1845                  I Monelli Pizza
# 55                   Birreria Tortuga
# 226              Ristorante Da Teresa
# 297                         Just Cafe
# 309                            Gnulot
# 1013                      BebelMilano
# Name: Name, dtype: object

# %%
df.loc[(df['Name'] == restaurant_name) | (df['Name'].isin(recommendations))]
# Out:
#       index                           Name   City  \
# 11    34378                       Gaffurio  Milan
# 55    10364               Birreria Tortuga  Milan
# 226   84230           Ristorante Da Teresa  Milan
# 297   43581                      Just Cafe  Milan
# 309   35819                         Gnulot  Milan
# 444   75413               Pizzeria Del 333  Milan
# 731   75419           Pizzeria Dell'Angelo  Milan
# 1013   9036                    BebelMilano  Milan
# 1845  40302                I Monelli Pizza  Milan
# 2843   2062  Al Meazza Ristorante Pizzeria  Milan
# 3133  75899    Pizzeria Trattoria S. Maria  Milan
#
#                              Cuisine Style  Ranking  Rating Price Range  \
# 11                        [italian, pizza]   5931.0     3.0       cheap
# 55                      [italian, brewpub]   5963.0     2.5       cheap
# 226                              [italian]   5364.0     3.0       cheap
# 297                              [italian]   2362.0     4.5       cheap
# 309                              [italian]   2142.0     5.0       cheap
# 444   [italian, pizza, vegetarianfriendly]    784.0     4.5       cheap
# 731   [italian, pizza, vegetarianfriendly]   1249.0     4.0       cheap
# 1013                             [italian]   2402.0     5.0       cheap
# 1845       [italian, pizza, mediterranean]    768.0     4.5       cheap
# 2843                      [italian, pizza]   4996.0     3.5       cheap
# 3133                      [italian, pizza]   1901.0     4.0       cheap
#
#                               keyword
# 11                  milan cheap pizza
# 55                        milan cheap
# 226                       milan cheap
# 297                       milan cheap
# 309                       milan cheap
# 444      milan cheap vegetarian pizza
# 731      milan cheap vegetarian pizza
# 1013                      milan cheap
# 1845  milan cheap mediterranean pizza
# 2843                milan cheap pizza
# 3133                milan cheap pizza
