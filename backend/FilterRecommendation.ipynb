# %%
import pandas as pd
import numpy as np
from re import sub

df = pd.read_csv('../data/dataset.csv', encoding='latin1')

# %%
df = df.iloc[:, 1:].copy()
df = df.dropna()
df.shape
# Out:
# (71477, 7)

# %%
df['City'] = df['City'].str.capitalize()
df['Cuisine Style'] = df['Cuisine Style'].str.lower()
df['keyword'] = df['keyword'].str.lower()
df['keyword'] = df['keyword'].str.strip()

df['Cuisine Style'] = df['Cuisine Style'].apply(lambda x: ' '.join(x.split(',')).split())
df['keyword'] = df['keyword'].apply(lambda x: sub(' +', ' ', x))

df = df.sort_values(['Ranking', 'Rating'], ascending=[True, False])

# %%
df.sample(10)
# Out:
#                                     Name       City  \
# 75221                   Pizzart Da Gimmy      Milan
# 93776                   Taberna El Paisa    Hamburg
# 40038   Hukka Restaurant & Hookah Lounge     Zurich
# 34604                              Gandl     Munich
# 12956             Breaking Bread Bistrot       Rome
# 92968                 Sushi Sun Magliana       Rome
# 33620                       Frau Larsson    Hamburg
# 46559                    Kungliga Operan  Stockholm
# 14528           Caco & Co Shepherds Bush     London
# 106125                 Xarcuteria Molina  Barcelona
#
#                                             Cuisine Style  Ranking  Rating  \
# 75221                                [vegetarianfriendly]   1239.0     4.0
# 93776                                    [latin, spanish]    823.0     4.0
# 40038          [german, belgian, mediterranean, european]   1601.0     1.0
# 34604     [european, centraleuropean, vegetarianfriendly]    407.0     4.0
# 12956                                      [veganoptions]   1061.0     4.5
# 92968             [chinese, japanese, vegetarianfriendly]   3522.0     3.5
# 33620                                 [european, swedish]    457.0     4.5
# 46559                                 [european, swedish]    901.0     4.5
# 14528   [mediterranean, european, portuguese, vegetari...   1849.0     4.5
# 106125                                    [mediterranean]   5452.0     3.5
#
#        Price Range                                            keyword
# 75221        cheap                             milan cheap vegetarian
# 93776       casual       hamburg casual southamerican westerneuropean
# 40038        fancy         zurich fancy mediterranean westerneuropean
# 34604       casual           munich casual vegetarian centraleuropean
# 12956        cheap                              rome cheap vegetarian
# 92968        cheap                        rome cheap vegetarian asian
# 33620       casual                    hamburg casual northerneuropean
# 46559       casual                  stockholm casual northerneuropean
# 14528       casual  london casual vegetarian mediterranean western...
# 106125      casual                     barcelona casual mediterranean

# %%
params = {'cuisine': 'any food', 'price': 'any price', 'city': 'anywhere'}

def find_restaurant(df, cuisine=params['cuisine'], price=params['price'], city=params['city'], num=5):
    condition = None
    multiple = False
    
    if (cuisine != params['cuisine']):
        condition = df['Cuisine Style'].str.contains(cuisine.lower(), regex=False)
        multiple = True
    
    if (price != params['price']):
        if multiple:
            condition = condition & (df['Price Range'] == price.lower())
        else:
            condition = df['Price Range'] == price.lower()
            multiple = True

    if (city != params['city']):
        if multiple:
            condition = condition & (df['City'].str.lower() == city.lower())
        else:
            condition = df['City'].str.lower() == city.lower()
    
    gl = df[condition].sort_values(['Ranking', 'Rating'], ascending=[True, False])
    
    return gl.head(num)

# %%
find_restaurant(df, city='Hamburg', price='casual', cuisine='german')
# Out:
#                                 Name     City  \
# 34768                     Gassenhaur  Hamburg
# 73513            Philipps Restaurant  Hamburg
# 25367                       Das Dorf  Hamburg
# 80548    Restaurant Krameramtsstuben  Hamburg
# 2813   Alt Helgolaender Fischerstube  Hamburg
#
#                                            Cuisine Style  Ranking  Rating  \
# 34768  [german, austrian, diner, winebar, vegetarianf...      3.0     5.0
# 73513  [international, french, german, european, cent...      4.0     5.0
# 25367  [german, european, centraleuropean, gastropub,...     16.0     4.5
# 80548  [healthy, german, european, centraleuropean, v...     20.0     4.5
# 2813   [german, seafood, european, centraleuropean, v...     22.0     4.5
#
#       Price Range                                            keyword
# 34768      casual          hamburg casual vegetarian westerneuropean
# 73513      casual  hamburg casual vegetarian international centra...
# 25367      casual  hamburg casual vegetarian centraleuropean west...
# 80548      casual  hamburg casual vegetarian healthy centraleurop...
# 2813       casual  hamburg casual vegetarian seafood centraleurop...
