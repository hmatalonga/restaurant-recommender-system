# %%
import pandas as pd
import numpy as np

df = pd.read_csv('./data/TA_restaurants_curated.csv')

# %%
df = df.iloc[:, 1:7].copy()
df = df.sample(500)
df.head()
# Out:
#                  Name        City  \
# 64205    Banana's Bar  Luxembourg
# 57955        1897 Ltd      London
# 105742         Apetit      Prague
# 87052   Casa da Horta      Oporto
# 88818       Coco Vika        Oslo
#
#                                             Cuisine Style  Ranking  Rating  \
# 64205                                             ['Bar']    414.0     3.5
# 57955                                                 NaN  12385.0     4.0
# 105742                                                NaN   1473.0     4.0
# 87052   ['European', 'Portuguese', 'Vegetarian Friendl...    449.0     4.5
# 88818   ['Asian', 'Vegetarian Friendly', 'Gluten Free ...    635.0     4.0
#
#        Price Range
# 64205     $$ - $$$
# 57955          NaN
# 105742         NaN
# 87052            $
# 88818     $$ - $$$

# %%
df = df.dropna()

# %%
df['Price Range'] = df['Price Range'].astype('category')
df['Price Range'].value_counts()
# Out:
# $$ - $$$    220
# $            72
# $$$$         19
# Name: Price Range, dtype: int64

# %%
# Parse the stringified features into their corresponding python objects
from ast import literal_eval

features = ['Cuisine Style']
for feature in features:
    df[feature] = df[feature].apply(literal_eval)

# %%
# Function to convert all strings to lower case and strip names of spaces
def clean_data(x):
    if isinstance(x, list):
        return [str.lower(i.replace(" ", "")) for i in x]
    else:
        #Check if director exists. If not, return empty string
        if isinstance(x, str):
            return str.lower(x.replace(" ", ""))
        else:
            return ''

features = ['City', 'Cuisine Style']
for feature in features:
    df[feature] = df[feature].apply(clean_data)

df.head()
# Out:
#                   Name        City  \
# 64205     Banana's Bar  luxembourg
# 87052    Casa da Horta      oporto
# 88818        Coco Vika        oslo
# 63920  Persian FoodBox  luxembourg
# 94148      Palace Cafe       paris
#
#                                            Cuisine Style  Ranking  Rating  \
# 64205                                              [bar]    414.0     3.5
# 87052  [european, portuguese, vegetarianfriendly, veg...    449.0     4.5
# 88818     [asian, vegetarianfriendly, glutenfreeoptions]    635.0     4.0
# 63920                           [middleeastern, persian]    129.0     4.5
# 94148                       [european, french, bar, pub]   4752.0     4.0
#
#       Price Range
# 64205    $$ - $$$
# 87052           $
# 88818    $$ - $$$
# 63920           $
# 94148    $$ - $$$

# %%
def create_soup(x):
    return ' '.join(x['Cuisine Style']) + ' ' + x['City']

df['soup'] = df.apply(create_soup, axis=1)
df.head()
# Out:
#                   Name        City  \
# 64205     Banana's Bar  luxembourg
# 87052    Casa da Horta      oporto
# 88818        Coco Vika        oslo
# 63920  Persian FoodBox  luxembourg
# 94148      Palace Cafe       paris
#
#                                            Cuisine Style  Ranking  Rating  \
# 64205                                              [bar]    414.0     3.5
# 87052  [european, portuguese, vegetarianfriendly, veg...    449.0     4.5
# 88818     [asian, vegetarianfriendly, glutenfreeoptions]    635.0     4.0
# 63920                           [middleeastern, persian]    129.0     4.5
# 94148                       [european, french, bar, pub]   4752.0     4.0
#
#       Price Range                                               soup
# 64205    $$ - $$$                                     bar luxembourg
# 87052           $  european portuguese vegetarianfriendly veganop...
# 88818    $$ - $$$    asian vegetarianfriendly glutenfreeoptions oslo
# 63920           $                   middleeastern persian luxembourg
# 94148    $$ - $$$                      european french bar pub paris

# %%
# Import CountVectorizer and create the count matrix
from sklearn.feature_extraction.text import CountVectorizer

count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(df['soup'])

# %%
# Compute the Cosine Similarity matrix based on the count_matrix
from sklearn.metrics.pairwise import cosine_similarity

cosine_sim = cosine_similarity(count_matrix, count_matrix)

# %%
# Reset index of our main DataFrame and construct reverse mapping as before
df = df.reset_index()
indices = pd.Series(df.index, index=df['Name'])

# %%
# Function that takes in movie title as input and outputs most similar movies
def get_recommendations(title, cosine_sim=cosine_sim):
    # Get the index of the movie that matches the title
    idx = indices[title]

    # Get the pairwsie similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar movies
    sim_scores = sim_scores[1:11]

    # Get the restaurants indices
    restaurants_indices = [i[0] for i in sim_scores]

    # Return the top 10 most similar movies
    return df['Name'].iloc[restaurants_indices]

# %%
df.head(15)
# Out:
#      index                         Name        City  \
# 0    64205                 Banana's Bar  luxembourg
# 1    87052                Casa da Horta      oporto
# 2    88818                    Coco Vika        oslo
# 3    63920              Persian FoodBox  luxembourg
# 4    94148                  Palace Cafe       paris
# 5    84958  Lezizel Manti - RiemArcaden      munich
# 6    35528                 Pulvermuehle     hamburg
# 7    23655                      Hanedan    brussels
# 8   117882               Bangkok-Vienna      vienna
# 9    16011                       Gogogi      berlin
# 10   97716          Le Cafe De La Poste       paris
# 11    1839        Restaurant District 5   amsterdam
# 12   87006         Restaurante Girassol      oporto
# 13   98427            La Goutte de Lait       paris
# 14    9203                      El Nilo   barcelona
#
#                                         Cuisine Style  Ranking  Rating  \
# 0                                               [bar]    414.0     3.5
# 1   [european, portuguese, vegetarianfriendly, veg...    449.0     4.5
# 2      [asian, vegetarianfriendly, glutenfreeoptions]    635.0     4.0
# 3                            [middleeastern, persian]    129.0     4.5
# 4                        [european, french, bar, pub]   4752.0     4.0
# 5                                           [turkish]   1361.0     5.0
# 6                                 [bar, pizza, diner]    149.0     4.5
# 7                                           [turkish]   1714.0     4.0
# 8   [asian, thai, vegetarianfriendly, veganoptions...     99.0     4.5
# 9   [barbecue, asian, korean, vegetarianfriendly, ...   2216.0     4.0
# 10                                           [french]   8320.0     5.0
# 11          [italian, mediterranean, pizza, european]   1844.0     4.0
# 12              [european, portuguese, mediterranean]    403.0     4.5
# 13                                           [french]   9032.0     4.0
# 14                          [mediterranean, egyptian]   3832.0     4.0
#
#    Price Range                                               soup
# 0     $$ - $$$                                     bar luxembourg
# 1            $  european portuguese vegetarianfriendly veganop...
# 2     $$ - $$$    asian vegetarianfriendly glutenfreeoptions oslo
# 3            $                   middleeastern persian luxembourg
# 4     $$ - $$$                      european french bar pub paris
# 5     $$ - $$$                                     turkish munich
# 6     $$ - $$$                            bar pizza diner hamburg
# 7     $$ - $$$                                   turkish brussels
# 8     $$ - $$$  asian thai vegetarianfriendly veganoptions glu...
# 9     $$ - $$$  barbecue asian korean vegetarianfriendly vegan...
# 10    $$ - $$$                                       french paris
# 11    $$ - $$$     italian mediterranean pizza european amsterdam
# 12    $$ - $$$           european portuguese mediterranean oporto
# 13    $$ - $$$                                       french paris
# 14           $                   mediterranean egyptian barcelona

# %%
get_recommendations('Gogogi')
# Out:
# 272                           Cooking Papa
# 86     Samadhi Vegan Vegetarian Restaurant
# 56                     Restaurant Tim Raue
# 216                               Melo-Jia
# 245                                 Orient
# 270                                Dosanko
# 8                           Bangkok-Vienna
# 49                          Malaysian Deli
# 97                               Thai Thai
# 125                        an an Asia Food
# Name: Name, dtype: object

# %%
df[(df['Name'] == 'Gogogi') | (df['Name'] == 'Cooking Papa')]
# Out:
#      index          Name    City  \
# 9    16011        Gogogi  berlin
# 272  15356  Cooking Papa  berlin
#
#                                          Cuisine Style  Ranking  Rating  \
# 9    [barbecue, asian, korean, vegetarianfriendly, ...   2216.0     4.0
# 272                                    [asian, korean]   1561.0     4.5
#
#     Price Range                                               soup
# 9      $$ - $$$  barbecue asian korean vegetarianfriendly vegan...
# 272    $$ - $$$                                asian korean berlin
